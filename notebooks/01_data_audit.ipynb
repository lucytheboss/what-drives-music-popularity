# %% [markdown]
# # 01 — Data Audit (Trust & Definitions)
#
# This notebook answers one question:
# **Can we trust this dataset enough to analyze what drives music popularity?**
#
# We will:
# 1. Verify schema + missingness + duplicates
# 2. Validate ranges + unit consistency (tempo, duration, loudness, etc.)
# 3. Define the target variable ("popularity") and known confounds
# 4. Produce a modeling-ready table and a data dictionary

# %%
import pandas as pd
import numpy as np

# %%
df_raw = pd.read_csv("../data/raw/apple_music_dataset.csv")
track_df = df_raw.copy()

display(track_df.head())
display(track_df.tail())
# Out:
#    artistId    artistName              collectionCensoredName  collectionId  \
# 0     46087  Erick Sermon                               Music     298321651
# 1     20044       Madonna                               Music      80815197
# 2    486597       Journey       Greatest Hits (2024 Remaster)     169003304
# 3    156987    Jason Mraz  We Sing. We Dance. We Steal Things     277635758
# 4     46087  Erick Sermon                               Music     298429528
#
#                        collectionName  collectionPrice contentAdvisoryRating  \
# 0                               Music             9.99              Explicit
# 1                               Music             9.99                   NaN
# 2       Greatest Hits (2024 Remaster)            10.99                   NaN
# 3  We Sing. We Dance. We Steal Things            11.99                   NaN
# 4                               Music             9.99                 Clean
#
#   country currency  discCount  ...  primaryGenreName           releaseDate  \
# 0     USA      USD          1  ...       Hip-Hop/Rap  2001-08-27T12:00:00Z
# 1     USA      USD          1  ...               Pop  2000-08-21T07:00:00Z
# 2     USA      USD          1  ...              Rock  1981-06-03T07:00:00Z
# 3     USA      USD          1  ...               Pop  2008-02-12T08:00:00Z
# 4     USA      USD          1  ...       Hip-Hop/Rap  2001-05-29T07:00:00Z
#
#                       trackCensoredName trackCount trackExplicitness  \
# 0             Music (feat. Marvin Gaye)         16          explicit
# 1                                 Music         10       notExplicit
# 2  Don't Stop Believin' (2024 Remaster)         16       notExplicit
# 3                             I'm Yours         12       notExplicit
# 4             Music (feat. Marvin Gaye)         16           cleaned
#
#      trackId                             trackName  trackNumber trackPrice  \
# 0  298321904                                 Music            4       1.29
# 1   80815173                                 Music            1       1.29
# 2  169003415  Don't Stop Believin' (2024 Remaster)            2       1.29
# 3  277635828                             I'm Yours            2       1.29
# 4  298429596                                 Music            4       1.29
#
#    trackTimeMillis
# 0           223133
# 1           225973
# 2           250835
# 3           242947
# 4           223133
#
# [5 rows x 24 columns]
#        artistId                    artistName  \
# 9995    5192163  Dave Matthews & Tim Reynolds
# 9996  214135551                           Red
# 9997     121582            The Isley Brothers
# 9998   91157642     David Eisley & Bob Kulick
# 9999     540530                   Pat Benatar
#
#                         collectionCensoredName  collectionId  \
# 9995  Live At Radio City (Bonus Track Version)     261552981
# 9996                       Until We Have Faces     416155893
# 9997              The Essential Isley Brothers     198017385
# 9998  Spongebob Squarepants - The Yellow Album     283379708
# 9999                             Greatest Hits     715881927
#
#                                 collectionName  collectionPrice  \
# 9995  Live At Radio City (Bonus Track Version)            12.99
# 9996                       Until We Have Faces             9.99
# 9997              The Essential Isley Brothers            14.99
# 9998  Spongebob Squarepants - The Yellow Album             9.99
# 9999                             Greatest Hits             9.99
#
#      contentAdvisoryRating country currency  discCount  ...  primaryGenreName  \
# 9995                   NaN     USA      USD          2  ...              Rock
# 9996                   NaN     USA      USD          1  ...              Rock
# 9997                   NaN     USA      USD          2  ...          R&B/Soul
# 9998                   NaN     USA      USD          1  ...  Children's Music
# 9999                   NaN     USA      USD          1  ...              Rock
#
#                releaseDate             trackCensoredName trackCount  \
# 9995  2007-08-14T12:00:00Z          So Damn Lucky (Live)         14
# 9996  2011-02-01T12:00:00Z                      Faceless         11
# 9997  1973-07-14T07:00:00Z         That Lady, Pts. 1 & 2         18
# 9998  2005-11-15T12:00:00Z                 Sweet Victory         23
# 9999  1979-08-27T07:00:00Z  Heartbreaker (2005 Remaster)         20
#
#      trackExplicitness    trackId                     trackName  trackNumber  \
# 9995       notExplicit  261553091                 So Damn Lucky            6
# 9996       notExplicit  416155943                      Faceless            2
# 9997       notExplicit  198017838         That Lady, Pts. 1 & 2            2
# 9998       notExplicit  283379767                 Sweet Victory            2
# 9999       notExplicit  715882411  Heartbreaker (2005 Remaster)            1
#
#      trackPrice  trackTimeMillis
# 9995       1.29           411640
# 9996       1.29           203520
# 9997       1.29           334387
# 9998       1.29           126653
# 9999       1.29           208307
#
# [5 rows x 24 columns]

# %% [markdown]
# # Fetching Data
# - get popularity data from spotify API

# %%
import os
from dotenv import load_dotenv

load_dotenv()

CLIENT_ID = os.getenv("SPOTIFY_CLIENT_ID")
CLIENT_SECRET = os.getenv("SPOTIFY_CLIENT_SECRET")

assert CLIENT_ID is not None
assert CLIENT_SECRET is not None

# %% [markdown]
# ## GEt Track Info

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
from tqdm import tqdm # Progress bar

URI = 'http://127.0.0.1:9090/callback'

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id=CLIENT_ID,
    client_secret=CLIENT_SECRET,
    redirect_uri=URI,
    scope="user-read-private"
))

def get_spotify_details(row):
    artist = str(row['artistName']).replace("'", "")
    track = str(row['trackName']).replace("'", "")
    query = f"track:{track} artist:{artist}"
    
    try:
        results = sp.search(q=query, type='track', limit=1)
        items = results['tracks']['items']
        
        if not items:
            return None 
        
        t = items[0]
        
        return {
            "spotify_id": t['id'],
            "spotify_artist_id": t['artists'][0]['id'],
            "spotify_popularity": t['popularity'],
            "spotify_explicit": t['explicit'],
            "cover_art_url": t['album']['images'][0]['url'] if t['album']['images'] else None,
            "spotify_release_date": t['album']['release_date']
        }
        
    except Exception as e:
        return None

print("⏳ Searching Spotify...")
tqdm.pandas()
spotify_data = track_df.progress_apply(get_spotify_details, axis=1)


clean_data = [x if x is not None else {} for x in spotify_data]
df_spotify_features = pd.DataFrame(clean_data)

# Merge
final_df = pd.concat([track_df.reset_index(drop=True), df_spotify_features], axis=1)

print(f"✅ Match Success Rate: {final_df['spotify_id'].notna().mean():.2%}")
display(final_df.head())
# Out:
# ⏳ Searching Spotify...
# 100%|██████████| 10000/10000 [42:21<00:00,  3.93it/s]
# ✅ Match Success Rate: 95.41%
#    artistId    artistName              collectionCensoredName  collectionId  \
# 0     46087  Erick Sermon                               Music     298321651
# 1     20044       Madonna                               Music      80815197
# 2    486597       Journey       Greatest Hits (2024 Remaster)     169003304
# 3    156987    Jason Mraz  We Sing. We Dance. We Steal Things     277635758
# 4     46087  Erick Sermon                               Music     298429528
#
#                        collectionName  collectionPrice contentAdvisoryRating  \
# 0                               Music             9.99              Explicit
# 1                               Music             9.99                   NaN
# 2       Greatest Hits (2024 Remaster)            10.99                   NaN
# 3  We Sing. We Dance. We Steal Things            11.99                   NaN
# 4                               Music             9.99                 Clean
#
#   country currency  discCount  ...                             trackName  \
# 0     USA      USD          1  ...                                 Music
# 1     USA      USD          1  ...                                 Music
# 2     USA      USD          1  ...  Don't Stop Believin' (2024 Remaster)
# 3     USA      USD          1  ...                             I'm Yours
# 4     USA      USD          1  ...                                 Music
#
#   trackNumber trackPrice trackTimeMillis              spotify_id  \
# 0           4       1.29          223133  6IFOw9Ck9mWHRQgw6QrPYx
# 1           1       1.29          225973  6WzRpISELf3YglGAh7TXcG
# 2           2       1.29          250835  5ehcf6UL1TkwozB386cRAp
# 3           2       1.29          242947  1EzrEOXmMH3G43AXT1y7pA
# 4           4       1.29          223133  6IFOw9Ck9mWHRQgw6QrPYx
#
#         spotify_artist_id spotify_popularity  spotify_explicit  \
# 0  2VX0o9LDIVmKIgpnwdJpOJ               56.0              True
# 1  1Xyo4u8uXC1ZmMpatF05PJ               84.0              True
# 2  0rvjqX7ttXeg3mTy8Xscbt               63.0             False
# 3  4phGZZrJZRo4ElhRtViYdl               77.0             False
# 4  2VX0o9LDIVmKIgpnwdJpOJ               56.0              True
#
#                                        cover_art_url  spotify_release_date
# 0  https://i.scdn.co/image/ab67616d0000b2737276e4...            2001-10-29
# 1  https://i.scdn.co/image/ab67616d0000b2734c8f09...            2023-06-02
# 2  https://i.scdn.co/image/ab67616d0000b27370b5c1...            1988-11-29
# 3  https://i.scdn.co/image/ab67616d0000b273125b1a...            2008-05-12
# 4  https://i.scdn.co/image/ab67616d0000b2737276e4...            2001-10-29
#
# [5 rows x 30 columns]

# %%
final_df.to_csv("../data/backup/popularity_df_backup.csv", index=False)

# %% [markdown]
# ## Get Artist Info

# %%
print(f"🎤 Artists to fetch: {final_df['spotify_artist_id'].nunique()}")

unique_ids = final_df['spotify_artist_id'].dropna().unique().tolist()

batch_size = 50
artist_data = []

print("Fetching Artist Popularity & Other Info...")
for i in tqdm(range(0, len(unique_ids), batch_size)):
    batch = unique_ids[i:i + batch_size]
    
    try:
        response = sp.artists(batch)
        for artist in response['artists']:
            image_url = artist['images'][0]['url'] if artist['images'] else None
            
            artist_data.append({
                "spotify_artist_id": artist['id'],
                "artist_popularity": artist['popularity'],
                "artist_genres": artist['genres'],
                "artist_followers": artist['followers']['total'],
                "artist_image_url": image_url  # <--- NEW FIELD ADDED HERE
            })
    except Exception as e:
        print(f"Error on batch {i}: {e}")

df_artists_only = pd.DataFrame(artist_data)
final_df = final_df.merge(df_artists_only, on="spotify_artist_id", how="left")

print("✅ Added Artist Info!")
display(final_df[['trackName', 'artist_popularity']].head())
# Out:
# 🎤 Artists to fetch: 1652
# Fetching Artist Popularity & Other Info...
# 100%|██████████| 34/34 [00:07<00:00,  4.62it/s]
# ✅ Added Artist Info!
#                               trackName  artist_popularity
# 0                                 Music               52.0
# 1                                 Music               96.0
# 2  Don't Stop Believin' (2024 Remaster)               76.0
# 3                             I'm Yours               74.0
# 4                                 Music               52.0

# %%
final_df.to_csv("../data/analysis/data.csv", index=False)
